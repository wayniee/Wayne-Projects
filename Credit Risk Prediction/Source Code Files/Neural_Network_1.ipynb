# %% [markdown]
# ## Encoding

# %%
import pandas as pd

# %%
train_df = pd.read_csv('train_dataset.csv')
test_df = pd.read_csv('test_dataset.csv')

# %%
train_df
# Out:
#        CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0                1             1                0     -0.579661
# 1                0             0                1     -0.579661
# 2                0             0                0     -0.579661
# 3                0             0                0     -0.579661
# 4                0             1                1      0.767400
# ...            ...           ...              ...           ...
# 57841            0             0                0      3.461523
# 57842            1             0                0      0.767400
# 57843            1             0                1     -0.579661
# 57844            0             0                0     -0.579661
# 57845            0             0                0     -0.579661
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0             -0.728827             Pensioner  Secondary / secondary special
# ...

# %%
# Split train and test data into feature and response variables
X_train = train_df.drop(columns=["TYPE"])
y_train = train_df["TYPE"]
X_test = test_df.drop(columns=["TYPE"])
y_test = test_df["TYPE"]

# %%
# encode categorical
from sklearn.preprocessing import LabelEncoder

categorical_cols = train_df.select_dtypes(include=["object"]).columns

le = LabelEncoder()
for col in categorical_cols:
    X_train[col] = le.fit_transform(X_train[col].astype(str))
    X_test[col] = le.transform(X_test[col].astype(str))

X_train
# Out:
#        CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0                1             1                0     -0.579661
# 1                0             0                1     -0.579661
# 2                0             0                0     -0.579661
# 3                0             0                0     -0.579661
# 4                0             1                1      0.767400
# ...            ...           ...              ...           ...
# 57841            0             0                0      3.461523
# 57842            1             0                0      0.767400
# 57843            1             0                1     -0.579661
# 57844            0             0                0     -0.579661
# 57845            0             0                0     -0.579661
#
#        AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0             -0.728827                 1                    4
# 1             -0.728827                 1                    4
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57846 entries, 0 to 57845
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CODE_GENDER          57846 non-null  int64
#  1   FLAG_OWN_CAR         57846 non-null  int64
#  2   FLAG_OWN_REALTY      57846 non-null  int64
#  3   CNT_CHILDREN         57846 non-null  float64
#  4   AMT_INCOME_TOTAL     57846 non-null  float64
#  5   NAME_INCOME_TYPE     57846 non-null  int64
#  6   NAME_EDUCATION_TYPE  57846 non-null  int64
#  7   NAME_FAMILY_STATUS   57846 non-null  int64
#  8   NAME_HOUSING_TYPE    57846 non-null  int64
#  9   FLAG_MOBIL           57846 non-null  int64
#  10  FLAG_WORK_PHONE      57846 non-null  int64
#  11  FLAG_PHONE           57846 non-null  int64
#  12  FLAG_EMAIL           57846 non-null  int64
#  13  OCCUPATION_TYPE      57846 non-null  int64
#  14  CNT_FAM_MEMBERS      57846 non-null  float64
# ...

# %%
if y_train.dtype == 'object':
  le = LabelEncoder()
  y_train = le.fit_transform(y_train.astype(str))

y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 57846 entries, 0 to 57845
# Series name: TYPE
# Non-Null Count  Dtype
# --------------  -----
# 57846 non-null  int64
# dtypes: int64(1)
# memory usage: 452.1 KB

# %%
if y_test.dtype == 'object':
  le = LabelEncoder()
  y_test = le.fit_transform(y_test.astype(str))

# %%
# Convert dataframe to numpy for sklearn
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# %% [markdown]
# ## Model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
# Define a custom dataset for credit risk data
class CreditRiskDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# Create DataLoader
batch_size = 512
train_dataset = CreditRiskDataset(X_train, y_train)
test_dataset = CreditRiskDataset(X_test, y_test)

# Split training set into training and validation
train_size = int(0.8 * len(train_dataset))
valid_size = len(train_dataset) - train_size
train_dataset, valid_dataset = torch.utils.data.random_split(
    train_dataset, [train_size, valid_size]
)

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
# model
class CreditRiskMLP(nn.Module):
    def __init__(self, input_dim, hidden_dims, output_dim, dropout_rate=0.2):
        super(CreditRiskMLP, self).__init__()

        layers = []
        # Input layer
        layers.append(nn.Linear(input_dim, hidden_dims[0]))
        layers.append(nn.ReLU())
        layers.append(nn.Dropout(dropout_rate))

        # Hidden layers
        for i in range(len(hidden_dims) - 1):
            layers.append(nn.Linear(hidden_dims[i], hidden_dims[i+1]))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(dropout_rate))

        # Output layer
        layers.append(nn.Linear(hidden_dims[-1], output_dim))

        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %%
# model init

# hyperparams
hidden_dims = [128, 64, 32]  # Size of hidden layers
dropout_rate = 0.3
input_dim = X_train.shape[1]
num_classes = len(np.unique(y_train)) # binary class
learning_rate = 0.001 # AdamW
num_epochs = 10 # 10 epochs
early_stopping_patience = 10 # early stopping

# Initialize the model
model = CreditRiskMLP(
    input_dim=input_dim,
    hidden_dims=hidden_dims,
    output_dim=num_classes,
    dropout_rate=dropout_rate
)

# %%
# loss functions
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# train model
def train_model(model, train_loader, valid_loader, criterion, optimizer, device, epochs=50, early_stopping_patience=5):
    # Move model to device
    model.to(device)

    # Track best validation accuracy and model state
    best_val_acc = 0
    best_model_state = None
    patience_counter = 0

    train_losses = []
    valid_losses = []
    train_accs = []
    valid_accs = []

    for epoch in range(epochs):
        # Training phase
        model.train()
        train_loss = 0
        train_correct = 0
        train_total = 0

        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(features)
            loss = criterion(outputs, labels)

            # Backward pass and optimize
            loss.backward()
            optimizer.step()

            # Calculate training metrics
            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()

        train_loss /= len(train_loader)
        train_acc = 100 * train_correct / train_total

        # Validation phase
        model.eval()
        valid_loss = 0
        valid_correct = 0
        valid_total = 0

        with torch.no_grad():
            for features, labels in valid_loader:
                features, labels = features.to(device), labels.to(device)

                # Forward pass
                outputs = model(features)
                loss = criterion(outputs, labels)

                # Calculate validation metrics
                valid_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                valid_total += labels.size(0)
                valid_correct += (predicted == labels).sum().item()

        valid_loss /= len(valid_loader)
        valid_acc = 100 * valid_correct / valid_total

        # Store metrics for plotting
        train_losses.append(train_loss)
        valid_losses.append(valid_loss)
        train_accs.append(train_acc)
        valid_accs.append(valid_acc)

        # Print progress
        print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Valid Loss: {valid_loss:.4f}, Valid Acc: {valid_acc:.2f}%')

        # Check for early stopping
        if valid_acc > best_val_acc:
            best_val_acc = valid_acc
            best_model_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= early_stopping_patience:
                print(f'Early stopping triggered after epoch {epoch+1}')
                break

    # Load the best model
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    # Plot training and validation metrics
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(valid_losses, label='Valid Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(train_accs, label='Train Accuracy')
    plt.plot(valid_accs, label='Valid Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.tight_layout()
    plt.savefig('credit_risk_mlp_training.png')
    plt.close()

    return model

# %%
# eval model
def evaluate_model(model, test_loader, criterion, device):
    model.eval()
    test_loss = 0
    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for features, labels in test_loader:
            features, labels = features.to(device), labels.to(device)

            # Forward pass
            outputs = model(features)
            loss = criterion(outputs, labels)

            # Calculate metrics
            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)

            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    test_loss /= len(test_loader)
    accuracy = accuracy_score(all_labels, all_predictions) * 100

    print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.2f}%')
    print('\nClassification Report:')
    print(classification_report(all_labels, all_predictions))

    # Plot confusion matrix
    cm = confusion_matrix(all_labels, all_predictions)
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()

    # Add labels
    class_names = ['Not Default', 'Default']  # Update based on your actual classes
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Add values to the confusion matrix
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('credit_risk_mlp_confusion_matrix.png')
    plt.close()

    return accuracy, all_predictions

# %%
# device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# ### Original Loss Function

# %%
'''
# run model
# Train the model
print("Starting model training...")
model = train_model(
    model=model,
    train_loader=train_loader,
    valid_loader=valid_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    epochs=num_epochs,
    early_stopping_patience=early_stopping_patience
)

# Evaluate the model
print("\nEvaluating model on test set...")
accuracy, predictions = evaluate_model(
    model=model,
    test_loader=test_loader,
    criterion=criterion,
    device=device
)

# Save the model
torch.save(model.state_dict(), 'credit_risk_mlp_model.pth')
print("Model saved to 'credit_risk_mlp_model.pth'")
'''
# Out:
# '\n# run model\n# Train the model\nprint("Starting model training...")\nmodel = train_model(\n    model=model,\n    train_loader=train_loader,\n    valid_loader=valid_loader,\n    criterion=criterion,\n    optimizer=optimizer,\n    device=device,\n    epochs=num_epochs,\n    early_stopping_patience=early_stopping_patience\n)\n\n# Evaluate the model\nprint("\nEvaluating model on test set...")\naccuracy, predictions = evaluate_model(\n    model=model,\n    test_loader=test_loader,\n    criterion=criterion,\n    device=device\n)\n\n# Save the model\ntorch.save(model.state_dict(), \'credit_risk_mlp_model.pth\')\nprint("Model saved to \'credit_risk_mlp_model.pth\'")\n'

# %% [markdown]
# From the confusion matrix, there is a tendency for the model to predict default. To counter this, try to add a weight to the loss function.

# %% [markdown]
# ### Loss Function with Weights

# %%
# Calculate class weights inversely proportional to class frequencies
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)

# Use weighted loss function
criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# run model
# Train the model
print("Starting model training...")
model = train_model(
    model=model,
    train_loader=train_loader,
    valid_loader=valid_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    epochs=num_epochs,
    early_stopping_patience=early_stopping_patience
)

# Evaluate the model
print("\nEvaluating model on test set...")
accuracy, predictions = evaluate_model(
    model=model,
    test_loader=test_loader,
    criterion=criterion,
    device=device
)

# Save the model
torch.save(model.state_dict(), 'credit_risk_mlp_model.pth')
print("Model saved to 'credit_risk_mlp_model.pth'")
# Out:
# Starting model training...
# Epoch [1/10], Train Loss: 0.6761, Train Acc: 56.24%, Valid Loss: 0.6153, Valid Acc: 66.91%
# Epoch [2/10], Train Loss: 0.6039, Train Acc: 66.75%, Valid Loss: 0.5184, Valid Acc: 75.16%
# Epoch [3/10], Train Loss: 0.5395, Train Acc: 72.83%, Valid Loss: 0.4575, Valid Acc: 78.97%
# Epoch [4/10], Train Loss: 0.4932, Train Acc: 76.17%, Valid Loss: 0.4156, Valid Acc: 81.31%
# Epoch [5/10], Train Loss: 0.4573, Train Acc: 78.57%, Valid Loss: 0.3846, Valid Acc: 83.47%
# Epoch [6/10], Train Loss: 0.4290, Train Acc: 80.28%, Valid Loss: 0.3530, Valid Acc: 85.01%
# Epoch [7/10], Train Loss: 0.4003, Train Acc: 81.99%, Valid Loss: 0.3232, Valid Acc: 86.71%
# Epoch [8/10], Train Loss: 0.3801, Train Acc: 83.11%, Valid Loss: 0.2997, Valid Acc: 87.62%
# Epoch [9/10], Train Loss: 0.3614, Train Acc: 84.19%, Valid Loss: 0.2824, Valid Acc: 88.24%
# Epoch [10/10], Train Loss: 0.3457, Train Acc: 85.07%, Valid Loss: 0.2689, Valid Acc: 89.30%
#
# Evaluating model on test set...
# ...
