# %% [markdown]
# # **Cleaning and Preparation of data**

# %% [markdown]
# This dataset consists **more than 1000 of real products with their identification number listed in the Amazon marketplace** specifically from the region India. The currency used in the dataset is Rupee India and it will be converted to usd which is more universal.
#
# Before data analysis, it is important to clean and prepare data. The methods used to clean and prepare the data are as listed below:
#
# 1. Changing Data Types of Columns from object to Floats
# 2. Filling in Missing Information
# 3. Checking For Duplicate Rows
# 4. Creating Various New Columns

# %%
# Importing Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing Files
df = pd.read_csv('../source/amazon.csv')

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
#Checking Column Names

df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
#Checking Number of Rows and Columns

df.shape
# Out:
# (1465, 16)

# %%
#Checking Data Types for each Column

df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %% [markdown]
# Note that the currency being used in **Indian Rupee**.

# %%
#Changing the data type of discounted price and actual price

df['discounted_price'] = df['discounted_price'].str.replace("₹",'')
df['discounted_price'] = df['discounted_price'].str.replace(",",'')
df['discounted_price'] = df['discounted_price'].astype('float64')

df['actual_price'] = df['actual_price'].str.replace("₹",'')
df['actual_price'] = df['actual_price'].str.replace(",",'')
df['actual_price'] = df['actual_price'].astype('float64')

# %%
# converting from rupee to usd
conversion_rate = 0.012
df['actual_price'] = df['actual_price'] * conversion_rate
df['discounted_price'] =df['discounted_price'] * conversion_rate

# %%
#Changing Datatype and values in Discount Percentage

df['discount_percentage'] = df['discount_percentage'].str.replace('%','').astype('float64')

df['discount_percentage'] = df['discount_percentage'] / 100

df['discount_percentage']
# Out:
# 0       0.64
# 1       0.43
# 2       0.90
# 3       0.53
# 4       0.61
#         ...
# 1460    0.59
# 1461    0.25
# 1462    0.28
# 1463    0.26
# 1464    0.22
# Name: discount_percentage, Length: 1465, dtype: float64

# %%
#Finding unusual string in the rating column

df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 5.0      3
# 3.0      3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
#Inspecting the exception row

df.query('rating == "|"')
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            25.188
#
#       actual_price  discount_percentage rating rating_count  \
# 1279        29.988                 0.16      |          992
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# 1279  Decent product,doesn't pick up sand,Ok ok,Must...
#
#                                          review_content  \
# 1279  Does the job well,doesn't work on sand. though...
#
#                                                img_link  \
# 1279  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 1279  https://www.amazon.in/Eureka-Forbes-Vacuum-Cle...

# %% [markdown]
# I went to the amazon page to get the rating and found that the product id of **B08L12N5H1 has a rating of 4**. So I am going to give the item rating a 4.0 as well.
#
# Source: https://www.amazon.in/Eureka-Forbes-Vacuum-Cleaner-Washable/dp/B08L12N5H1

# %%
#Changing Rating Columns Data Type

df['rating'] = df['rating'].str.replace('|', '4.0').astype('float64')

# %%
#Changing Rating Column Data Type

df['rating_count'] = df['rating_count'].str.replace(',', '').astype('float64')

# %%
#Checking for Duplicates

duplicates = df.duplicated()
df[duplicates]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %%
#Checking Missing Values

df.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# ## Products Table

# %%
#Creating a new DataFrame with Selected Column to use for products table
df1 = df[['product_id', 'product_name', 'about_product','category', 'actual_price', 'discounted_price','discount_percentage','img_link']].copy()

# %%
df1['actual_price'] = df1['actual_price'].round(2)
df1['discounted_price'] = df1['discounted_price'].round(2)

# %%
df1[df1.duplicated()]
# Out:
#       product_id                                       product_name  \
# 622   B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 642   B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 658   B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 668   B08DDRGWTJ             MI Usb Type-C Cable Smartphone (Black)
# 684   B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 689   B085DTN6R2  Portronics Konnect CL 20W POR-1067 Type-C to 8...
# 692   B09KLVMZ3B  Portronics Konnect L 1.2M POR-1401 Fast Chargi...
# 714   B08DPLCM6T  LG 80 cm (32 inches) HD Ready Smart LED TV 32L...
# 727   B09NHVCHS9        Flix Micro Usb Cable For Smartphone (Black)
# 731   B01M4GGIVU  Tizum High Speed HDMI Cable with Ethernet | Su...
# 771   B077Z65HSD  boAt A400 USB Type-C to USB-A 2.0 Male Data Ca...
# 818   B09CMM3VGK  Ambrane 60W / 3A Type C Fast Charging Unbreaka...
# 836   B0B4HJNPV4  pTron Solero T351 3.5Amps Fast Charging Type-C...
# 852   B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 857   B07XJYYH7L  Wecool Nylon Braided Multifunction Fast Chargi...
# 885   B07232M876  Amazonbasics Micro Usb Fast Charging Cable For...
# 894   B07P681N66  TP-Link AC600 600 Mbps WiFi Wireless Network U...
# 925   B0B4DT8MKT  Wecool Unbreakable 3 in 1 Charging Cable with ...
# 938   B0994GFWBH  Lapster 1.5 mtr USB 2.0 Type A Male to USB A M...
# 968   B09Q8HMKZX  Portronics Konnect L 20W PD Quick Charge Type-...
# 974   B01GGKYKQM  Amazon Basics USB Type-C to USB-A 2.0 Male Fas...
# 983   B08R69VDHT  Pinnaclz Original Combo of 2 Micro USB Fast Ch...
# 985   B09RWZRCP1  boAt Type C A750 Stress Resistant, Tangle-free...
# 1000  B0B2DJDCPX  SWAPKART Fast Charging Cable and Data Sync USB...
# 1018  B0BMXMLSMM  Lapster 65W compatible for OnePlus Dash Warp C...
#
#                                           about_product  \
# 622   Compatible with all Type C enabled devices, be...
# 642   Fast Charging & Data Sync: Solero TB301 Type-C...
# 658   It Ensures High Speed Transmission And Chargin...
# 668   1m long Type-C USB Cable|Sturdy and Durable. W...
# 684   Flexible, lightweight HDMI cable for connectin...
# 689   [20W PD FAST CHARGING]-It’s supports 20W PD qu...
# 692   [CHARGE & SYNC FUNCTION]- This cable comes wit...
# 714   Resolution: HD Ready (1366x768) | Refresh Rate...
# 727   Micro usb cable is 1 meter in length, optimize...
# 731   Latest Standard HDMI A Male to A Male Cable: S...
# 771   2 meter special reversible Type-C to USB A mal...
# 818   Stay ahead and never miss out with a 3A and 30...
# 836   Universal Compatibility: Solero T351 USB charg...
# 852   One 6-foot-long (1.8 meters) high-speed multi-...
# 857   Special Features Of The Universal Cable: This ...
# 885   Cable Length: 6 Feet (1. 82 Meters)|Gold-Plate...
# 894   High-Speed Wi-Fi —— 256QAM support increases t...
# 925   Fast Charging Cable that can be used to charge...
# 938   Plug & Play|Stable & Reliable Connectivity.|Sp...
# 968   [1.2 M LONG DURABLE CABLE] : The Konnect L is ...
# 974   Connect USB Type-C enabled devices (MacBook, C...
# 983   [SYNC & CHARGE] : Ideal for charging and power...
# 985   The boAt Type C A750 cable is compatible with ...
# 1000  [High Compatibility] : This iphone data cable ...
# 1018  -1 meter type c to c cable fast charging cable...
#
#                                                category  actual_price  \
# 622   Computers&Accessories|Accessories&Peripherals|...          4.19
# 642   Computers&Accessories|Accessories&Peripherals|...         12.00
# 658   Computers&Accessories|Accessories&Peripherals|...          5.99
# 668   Computers&Accessories|Accessories&Peripherals|...          3.59
# 684   Electronics|HomeTheater,TV&Video|Accessories|C...          8.40
# 689   Computers&Accessories|Accessories&Peripherals|...         10.79
# 692   Computers&Accessories|Accessories&Peripherals|...          4.79
# 714   Electronics|HomeTheater,TV&Video|Televisions|S...        263.88
# 727   Computers&Accessories|Accessories&Peripherals|...          2.39
# 731   Electronics|HomeTheater,TV&Video|Accessories|C...          8.39
# 771   Computers&Accessories|Accessories&Peripherals|...         11.99
# 818   Computers&Accessories|Accessories&Peripherals|...          5.99
# 836   Computers&Accessories|Accessories&Peripherals|...         11.99
# 852   Computers&Accessories|Accessories&Peripherals|...          8.34
# 857   Computers&Accessories|Accessories&Peripherals|...         11.99
# 885   Computers&Accessories|Accessories&Peripherals|...          4.74
# 894   Computers&Accessories|NetworkingDevices|Networ...         26.39
# 925   Computers&Accessories|Accessories&Peripherals|...         17.99
# 938   Computers&Accessories|Accessories&Peripherals|...         11.99
# 968   Computers&Accessories|Accessories&Peripherals|...          8.39
# 974   Computers&Accessories|Accessories&Peripherals|...          8.40
# 983   Computers&Accessories|Accessories&Peripherals|...          5.99
# 985   Computers&Accessories|Accessories&Peripherals|...         11.99
# 1000  Computers&Accessories|Accessories&Peripherals|...          5.99
# 1018  Computers&Accessories|Accessories&Peripherals|...         11.99
#
#       discounted_price  discount_percentage  \
# 622               2.39                 0.43
# 642               1.79                 0.85
# 658               2.12                 0.65
# 668               2.75                 0.23
# 684               2.63                 0.69
# 689               4.20                 0.61
# 692               1.91                 0.60
# 714             161.88                 0.39
# 727               0.71                 0.70
# 731               2.39                 0.72
# 771               3.59                 0.70
# 818               2.15                 0.64
# 836               2.39                 0.80
# 852               2.51                 0.70
# 857               4.00                 0.67
# 885               2.39                 0.50
# 894              14.39                 0.45
# 925               4.18                 0.77
# 938               1.67                 0.86
# 968               3.16                 0.62
# 974               2.63                 0.69
# 983               1.38                 0.77
# 985               4.79                 0.60
# 1000              2.51                 0.58
# 1018              2.39                 0.80
#
#                                                img_link
# 622   https://m.media-amazon.com/images/W/WEBP_40237...
# 642   https://m.media-amazon.com/images/I/31wOPjcSxl...
# 658   https://m.media-amazon.com/images/W/WEBP_40237...
# 668   https://m.media-amazon.com/images/I/31XO-wfGGG...
# 684   https://m.media-amazon.com/images/I/41nPYaWA+M...
# 689   https://m.media-amazon.com/images/I/31J6qGhAL9...
# 692   https://m.media-amazon.com/images/W/WEBP_40237...
# 714   https://m.media-amazon.com/images/W/WEBP_40237...
# 727   https://m.media-amazon.com/images/I/31qGpf8uzu...
# 731   https://m.media-amazon.com/images/I/41da4tk7N+...
# 771   https://m.media-amazon.com/images/I/41jk4zYjTs...
# 818   https://m.media-amazon.com/images/W/WEBP_40237...
# 836   https://m.media-amazon.com/images/I/41wN7jooz0...
# 852   https://m.media-amazon.com/images/I/4101vlzySz...
# 857   https://m.media-amazon.com/images/W/WEBP_40237...
# 885   https://m.media-amazon.com/images/W/WEBP_40237...
# 894   https://m.media-amazon.com/images/I/216Q4FqmZV...
# 925   https://m.media-amazon.com/images/W/WEBP_40237...
# 938   https://m.media-amazon.com/images/I/310WOJIrwj...
# 968   https://m.media-amazon.com/images/I/41x3iKbD-+...
# 974   https://m.media-amazon.com/images/W/WEBP_40237...
# 983   https://m.media-amazon.com/images/I/41gFqSHngy...
# 985   https://m.media-amazon.com/images/I/41jlh3c7Ub...
# 1000  https://m.media-amazon.com/images/I/41KmCJuybR...
# 1018  https://m.media-amazon.com/images/W/WEBP_40237...

# %%
df[df['product_id'] == 'B096MSW6CT']
# Out:
#      product_id                                       product_name  \
# 2    B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 379  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 623  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                               category  discounted_price  \
# 2    Computers&Accessories|Accessories&Peripherals|...             2.388
# 379  Computers&Accessories|Accessories&Peripherals|...             2.388
# 623  Computers&Accessories|Accessories&Peripherals|...             2.388
#
#      actual_price  discount_percentage  rating  rating_count  \
# 2          22.788                  0.9     3.9        7928.0
# 379        11.988                  0.8     3.9        7928.0
# 623        11.988                  0.8     3.9        7928.0
#
#                                          about_product  \
# 2    【 Fast Charger& Data Sync】-With built-in safet...
# 379  【 Fast Charger& Data Sync】-With built-in safet...
# 623  【 Fast Charger& Data Sync】-With built-in safet...
#
#                                                user_id  \
# 2    AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 379  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 623  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
#
#                                              user_name  \
# 2    Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 379  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 623  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
#
#                                              review_id  \
# 2    R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 379  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 623  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
#
#                                           review_title  \
# 2    Good speed for earlier versions,Good Product,W...
# 379  Good speed for earlier versions,Good Product,W...
# 623  Good speed for earlier versions,Good Product,W...
#
#                                         review_content  \
# 2    Not quite durable and sturdy,https://m.media-a...
# 379  Not quite durable and sturdy,https://m.media-a...
# 623  Not quite durable and sturdy,https://m.media-a...
#
#                                               img_link  \
# 2    https://m.media-amazon.com/images/W/WEBP_40237...
# 379  https://m.media-amazon.com/images/I/31IvNJZnmd...
# 623  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                           product_link
# 2    https://www.amazon.in/Sounce-iPhone-Charging-C...
# 379  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 623  https://www.amazon.in/Sounce-iPhone-Charging-C...

# %%
df.loc[623].compare(df.loc[379])
# Out:
#                                                              self  \
# about_product   【 Fast Charger& Data Sync】-With built-in safet...
# review_content  Not quite durable and sturdy,https://m.media-a...
# img_link        https://m.media-amazon.com/images/W/WEBP_40237...
# product_link    https://www.amazon.in/Sounce-iPhone-Charging-C...
#
#                                                             other
# about_product   【 Fast Charger& Data Sync】-With built-in safet...
# review_content  Not quite durable and sturdy,https://m.media-a...
# img_link        https://m.media-amazon.com/images/I/31IvNJZnmd...
# product_link    https://www.amazon.in/Sounce-iPhone-Charging-C...

# %%
# Finding out the difference in the two entries
df.loc[623]==df.loc[379]
# Out:
# product_id              True
# product_name            True
# category                True
# discounted_price        True
# actual_price            True
# discount_percentage     True
# rating                  True
# rating_count            True
# about_product          False
# user_id                 True
# user_name               True
# review_id               True
# review_title            True
# review_content         False
# img_link               False
# product_link           False
# dtype: bool

# %% [markdown]
# To ensure all product_ids are unique in the products table, we will be dropping any duplicates and retaining the first occurence.

# %%
df1.drop_duplicates(subset=['product_id'],keep='first',inplace=True)

# %%
df1.shape
# Out:
# (1351, 8)

# %%
df1.to_csv("data/products.csv",index=False)

# %% [markdown]
# ## Ratings Table

# %%
#Creating a new DataFrame with Selected Column to use for ratings table
df2 = df[['product_id','rating','rating_count','review_title','review_content']].copy()

# %%
count_series = df2.groupby('product_id').count()['rating']
count_series[count_series > 1].index
# Out:
# Index(['B002PD61Y4', 'B008FWZGSG', 'B00NH11KIK', 'B00NH11PEY', 'B0141EZMAI',
#        'B01DEWVZ2C', 'B01FSYQ2A4', 'B01GGKYKQM', 'B01GGKZ0V6', 'B01M4GGIVU',
#        'B07232M876', 'B077Z65HSD', 'B0789LZTCJ', 'B078G6ZF5Z', 'B07DJLFMPS',
#        'B07GVGTSLN', 'B07JW9H4J1', 'B07KRCW6LZ', 'B07KSMBL2H', 'B07P681N66',
#        'B07RD611Z8', 'B07WG8PDCW', 'B07XJYYH7L', 'B07XLCFSSN', 'B082LSVT4B',
#        'B082LZGK39', 'B082T6V3DT', 'B083342NKJ', 'B085194JFL', 'B085DTN6R2',
#        'B085HY1DGR', 'B08BCKN299', 'B08BQ947H3', 'B08CDKQ8T6', 'B08CF3B7N1',
#        'B08CF3D7QR', 'B08DDRGWTJ', 'B08DPLCM6T', 'B08HDJ86NZ', 'B08K4PSZ3V',
#        'B08MTCKDYN', 'B08QSC1XY8', 'B08R69VDHT', 'B08WRBG3XW', 'B08WRWPM22',
#        'B08Y1SJVV5', 'B08Y1TFSP6', 'B0949SBKMP', 'B094JNXNPV', 'B094YFFSMY',
#        'B096MSW6CT', 'B096VF5YYF', 'B097R25DP7', 'B098NS6PVG', 'B0994GFWBH',
#        'B09C6HWG18', 'B09C6HXFC1', 'B09CMM3VGK', 'B09CMP1SC8', 'B09F6S8BT6',
#        'B09F9YQQ7B', 'B09KGV7WSV', 'B09KLVMZ3B', 'B09MQSCJQ1', 'B09MT84WV5',
#        'B09NHVCHS9', 'B09NVPSCQT', 'B09Q8HMKZX', 'B09RWZRCP1', 'B09RZS1NQT',
#        'B09V12K8NT', 'B09W5XR9RT', 'B09YLXYP7Y', 'B09YV4MW2T', 'B09YV4RG4D',
#        'B09Z6WH2N1', 'B09ZQK9X8G', 'B0B2DJDCPX', 'B0B3MWYCHQ', 'B0B3N7LR6K',
#        'B0B3RRWSF6', 'B0B4DT8MKT', 'B0B4HJNPV4', 'B0B5B6PQCT', 'B0B5LVS732',
#        'B0B5ZF3NRK', 'B0B86CDHL1', 'B0B9BD2YL4', 'B0B9BXKBC7', 'B0BDRVFDKP',
#        'B0BFWGBX61', 'B0BMXMLSMM'],
#       dtype='object', name='product_id')

# %% [markdown]
# There are product ids with more than 1 rating, so I will take the average of their ratings and concatenate the review titles and contents.

# %%
avg_ratings = df2.groupby('product_id')['rating'].mean().reset_index()
avg_ratings.rename(columns={'rating': 'average_rating'}, inplace=True)

# %%
# Concatenate review_title and review_content for each product_id
concatenated_titles = df2.groupby('product_id')['review_title'].apply(lambda x: ' | '.join(x)).reset_index()
concatenated_contents = df2.groupby('product_id')['review_content'].apply(lambda x: ' | '.join(x)).reset_index()

# Combine the results into one DataFrame
result = avg_ratings.merge(concatenated_titles, on='product_id')
result = result.merge(concatenated_contents, on='product_id')

# %%
total_rating_counts = df2.groupby('product_id')['rating_count'].sum().reset_index()
result = result.merge(total_rating_counts, on='product_id')

# %%
result['rating_count'] = result['rating_count'].astype(int)

# %%
result.to_csv('data/ratings.csv',index=False)

# %%
result.head()
# Out:
#    product_id  average_rating  \
# 0  B002PD61Y4             4.1
# 1  B002SZEOLG             4.2
# 2  B003B00484             4.3
# 3  B003L62T7W             4.3
# 4  B004IO5BMQ             4.5
#
#                                         review_title  \
# 0  good tool to use for,Brand is always good,Over...
# 1  Works on linux for me. Get the model with ante...
# 2  Works Good,Perfect replacement cell for trimme...
# 3  Handy Mouse,Good quality mouse,Good one.,Good,...
# 4  Good silent mouse,Too small to hold!,Reviewing...
#
#                                       review_content  rating_count
# 0  good quality tool from d linkWiFi signal is go...         16262
# 1  I use this to connect an old PC to internet. I...        179692
# 2  Works good,Bought it to replace my Phillips QT...         27201
# 3  Liked this Product,https://m.media-amazon.com/...         31534
# 4  It's little small for big hands. But best avai...         54405

# %% [markdown]
# ## Daily Transaction History Table
# This version is outdated and no longer in use, refer to online_sales_cleaning.ipynb

# %%
# https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/YGLYDY
sales = pd.read_csv("../source/amazon-purchases.csv")
sales.shape
# Out:
#          Order Date  Purchase Price Per Unit  Quantity Shipping Address State  \
# 1601     2018-03-21                     7.99       1.0                     SD
# 2872     2022-11-27                     7.68       1.0                     KS
# 4832     2018-04-12                     3.99       1.0                     UT
# 5496     2020-12-24                    13.49       1.0                     UT
# 7115     2019-08-24                     9.29       1.0                     MI
# ...             ...                      ...       ...                    ...
# 1847559  2022-01-09                     6.99       1.0                     MD
# 1849170  2021-02-02                     8.61       1.0                     IL
# 1849692  2022-03-17                     9.21       1.0                     WI
# 1850677  2018-10-11                     8.99       1.0                     MA
# 1850678  2018-10-13                     8.49       1.0                     MA
#
#                                                      Title  \
# 1601     Amazon Basics High-Speed HDMI Cable (18 Gbps, ...
# 2872     Amazon Basics High-Speed HDMI Cable (18 Gbps, ...
# 4832     Amazon Basics HDMI Female to Female Coupler Ad...
# 5496     Amazon Basics Uni-Directional DisplayPort to H...
# 7115     Amazon Basics 16-Gauge Speaker Wire Cable, 50 ...
# ...                                                    ...
# 1847559  Logitech B100 Corded Mouse – Wired USB Mouse f...
# 1849170  Amazon Basics High-Speed HDMI Cable (18 Gbps, ...
# 1849692  Amazon Basics Uni-Directional DisplayPort to H...
# 1850677  Amazon Basics DisplayPort to DisplayPort 1.2 C...
# 1850678  Amazon Basics 16-Gauge Speaker Wire Cable, 50 ...
#
#         ASIN/ISBN (Product Code)            Category  Survey ResponseID
# 1601                  B014I8SX4Y    ELECTRONIC_CABLE  R_06RZP9pS7kONINr
# 2872                  B014I8SSD0    CABLE_OR_ADAPTER  R_0Arj0ePpTnReV1v
# 4832                  B06XR9PR5X  ELECTRONIC_ADAPTER  R_0DoXqOQl0hxEeFH
# 5496                  B015OW3M1W    ELECTRONIC_CABLE  R_0DoXqOQl0hxEeFH
# 7115                  B006LW0WDQ    ELECTRONIC_CABLE  R_0IBgnbXoP4Uvvhv
# ...                          ...                 ...                ...
# 1847559               B003L62T7W         INPUT_MOUSE  R_zTi3j2QuqAzr7NL
# 1849170               B014I8SSD0    ELECTRONIC_CABLE  R_zd4E1BgAdaM2761
# 1849692               B015OW3M1W    ELECTRONIC_CABLE  R_zdLOP8JD2pe1brj
# 1850677               B01J8S6X2I    ELECTRONIC_CABLE  R_zfqnsBzlOAKibzb
# 1850678               B006LW0WDQ    ELECTRONIC_CABLE  R_zfqnsBzlOAKibzb
#
# [887 rows x 8 columns]

# %%
df[df['product_id']=='B002SZEOLG']
# Out:
#      product_id                                       product_name  \
# 143  B002SZEOLG  TP-Link Nano USB WiFi Dongle 150Mbps High Gain...
#
#                                               category  discounted_price  \
# 143  Computers&Accessories|NetworkingDevices|Networ...             8.988
#
#      actual_price  discount_percentage  rating  rating_count  \
# 143        16.068                 0.44     4.2      179692.0
#
#                                          about_product  \
# 143  150 Mbps Wi-Fi —— Exceptional wireless speed u...
#
#                                                user_id  \
# 143  AGV3IEFANZCKECFGUM42MRH5FNOA,AEBO7NWCNXKT4AESA...
#
#                                              user_name  \
# 143  Azhar JuMan,Anirudh Sood,Hari Krishnan PS,Akas...
#
#                                              review_id  \
# 143  R1LW6NWSVTVZ2H,R3VR5WFKUS15C5,R2F6GC79OYWUKQ,R...
#
#                                           review_title  \
# 143  Works on linux for me. Get the model with ante...
#
#                                         review_content  \
# 143  I use this to connect an old PC to internet. I...
#
#                                               img_link  \
# 143  https://m.media-amazon.com/images/I/31Wb+A3VVd...
#
#                                           product_link
# 143  https://www.amazon.in/TP-Link-TL-WN722N-150Mbp...

# %%
sales_new[sales_new['ASIN/ISBN (Product Code)']=='B002SZEOLG']
# Out:
#          Order Date  Purchase Price Per Unit  Quantity Shipping Address State  \
# 1249384  2019-12-11                    14.99       1.0                     ID
#
#                                                      Title  \
# 1249384  TP-Link Nano USB Wifi Dongle 150Mbps High Gain...
#
#         ASIN/ISBN (Product Code)                              Category  \
# 1249384               B002SZEOLG  NETWORK_INTERFACE_CONTROLLER_ADAPTER
#
#          Survey ResponseID
# 1249384  R_3iJPosktkZFzmM4

# %%
sales_new= sales[sales["ASIN/ISBN (Product Code)"].isin(df['product_id'])]
sales_new.groupby('ASIN/ISBN (Product Code)')['Quantity'].count()
# Out:
# ASIN/ISBN (Product Code)
# B002SZEOLG      1
# B003L62T7W     63
# B005FYNT3G      1
# B005LJQMZC      1
# B006LW0WDQ     10
# B0088TKTY2      1
# B008IFXQFU     57
# B00MUTWLW4      7
# B00NH11KIK     48
# B00NH11PEY     30
# B00NH12R1O      4
# B00NH13Q8W      7
# B00SH18114      8
# B00ZYLMQH0     10
# B0148NPH9I     14
# B014I8SSD0    178
# B014I8SX4Y     31
# B015OW3M1W     46
# B01D5H8LDM      6
# B01D5H8ZI8     10
# B01D5H90L4      6
# B01EZ0X3L8      4
# B01GGKYKQM     26
# B01GGKZ0V6      5
# B01GGKZ4NU      4
# B01J8S6X2I     31
# B06XR9PR5X      4
# B0711PVX6Z     26
# B07232M876     40
# B073BRXPZX      2
# B075ZTJ9XR     12
# B07CWDX49D      2
# B07DC4RZPY     53
# B07G3YNLJB      4
# B07KSB1MLX      1
# B07KSMBL2H      2
# B07TMCXRFV      4
# B07VTFN6HM      6
# B07XLCFSSN      1
# B07ZR4S1G4      2
# B082T6GVG9      8
# B082T6GVLJ      4
# B082T6GXS5      5
# B082T6V3DT      9
# B086JTMRYL      1
# B08C4Z69LN     11
# B08GTYFC37     11
# B08GYG6T12     16
# B08JD36C6H      1
# B095RTJH1M     22
# B09BVCVTBC      1
# B09G5TSGXV     11
# B09X7DY7Q4      1
# B09YLFHFDW      1
# B0B1NX6JTN      3
# B0B23LW7NV      6
# B0B244R4KB      8
# Name: Quantity, dtype: int64

# %%
sales_new.head()
# Out:
#       Order Date  Purchase Price Per Unit  Quantity Shipping Address State  \
# 1601  2018-03-21                     7.99       1.0                     SD
# 2872  2022-11-27                     7.68       1.0                     KS
# 4832  2018-04-12                     3.99       1.0                     UT
# 5496  2020-12-24                    13.49       1.0                     UT
# 7115  2019-08-24                     9.29       1.0                     MI
#
#                                                   Title  \
# 1601  Amazon Basics High-Speed HDMI Cable (18 Gbps, ...
# 2872  Amazon Basics High-Speed HDMI Cable (18 Gbps, ...
# 4832  Amazon Basics HDMI Female to Female Coupler Ad...
# 5496  Amazon Basics Uni-Directional DisplayPort to H...
# 7115  Amazon Basics 16-Gauge Speaker Wire Cable, 50 ...
#
#      ASIN/ISBN (Product Code)            Category  Survey ResponseID
# 1601               B014I8SX4Y    ELECTRONIC_CABLE  R_06RZP9pS7kONINr
# 2872               B014I8SSD0    CABLE_OR_ADAPTER  R_0Arj0ePpTnReV1v
# 4832               B06XR9PR5X  ELECTRONIC_ADAPTER  R_0DoXqOQl0hxEeFH
# 5496               B015OW3M1W    ELECTRONIC_CABLE  R_0DoXqOQl0hxEeFH
# 7115               B006LW0WDQ    ELECTRONIC_CABLE  R_0IBgnbXoP4Uvvhv

# %%
sales_new.index
# Out:
# Index([   1601,    2872,    4832,    5496,    7115,    9966,   10787,   10902,
#          12653,   13115,
#        ...
#        1836353, 1838628, 1846239, 1846623, 1846868, 1847559, 1849170, 1849692,
#        1850677, 1850678],
#       dtype='int64', length=887)

# %%
sales_new['transaction_id'] = sales_new.index

# %%
sales_new['Quantity'] = sales_new['Quantity'].astype(int)

# %%
final_sales = sales_new[['transaction_id','Order Date','ASIN/ISBN (Product Code)','Quantity',]]

# %%
final_sales.to_csv("data/daily_sales.csv",index=False)
